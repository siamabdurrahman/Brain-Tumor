# %% [markdown]
# <a href="https://colab.research.google.com/github/siamabdurrahman/Brain-Tumour-Classification/blob/Brain-Tumour-Detection-from-MRI-Images-Using-Convolutional-Neural-Networks-and-Transfer-Learning/Brain-Tumour-Detection-from-MRI-Images-Using-Convolutional-Neural-Networks-and-Transfer-Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
